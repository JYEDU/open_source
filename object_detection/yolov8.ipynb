# %% [markdown]
# # Object Detection with YOLOv8

# %% [markdown]
# ## Reference
#
# [1] [[Github](https://github.com/ultralytics/ultralytics)] [[Docs](https://docs.ultralytics.com/ko/)] YOLOv8

# %% [markdown]
# ## Settings
# - Create and activate virtual environment
#     - conda create -n yolov8 python==3.10
#     - conda activate yolov8
#
# - Install library
#     - pip install torch torchvision (버전에 맞게 먼저 설치)
#     - pip install ultralytics

# %%
# gpu 사용 여부 확인
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# 설치 확인
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.22 🚀 Python-3.10.0 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# Setup complete ✅ (28 CPUs, 63.8 GB RAM, 281.5/1862.1 GB disk)

# %%
# Train
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')                    # bulid a new model from YAML
model = YOLO('yolov8n.pt')                      # load apretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt') # build from YAML and transfer weights

# Train the model
results = model.train(data='coco128.yaml',epochs=100, imgsz=640)
# Out:
# Transferred 355/355 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.1.23 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.22 🚀 Python-3.10.0 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %%
# Validation
from ultralytics import YOLO

#Load a model
model = YOLO('yolov8n.pt')                            # load an official model
model = YOLO('runs/detect/train/weights/best.pt')     # load a custom model

# Validate the model
metrics = model.val()                                 # no argments needed, dataset and settings remembered
metrics.box.map                                       # map50-95
metrics.box.map50                                     # map50
metrics.box.map75                                     # map75
metrics.box.maps                                      # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.1.22 🚀 Python-3.10.0 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning C:\Users\jyes9\datasets\coco128\labels\train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:03<00:00,  2.27it/s]
#                    all        128        929      0.661      0.532      0.611      0.453
#                 person        128        254      0.814      0.669      0.768      0.541
#                bicycle        128          6      0.556      0.333      0.316      0.264
#                    car        128         46      0.823      0.217      0.273      0.169
#             motorcycle        128          5      0.685      0.876      0.898      0.685
# ...

# %%
# Inference
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Define path to the image file
source = 'example.png'

# Run inference on the source -> list of Results objects
results = model(source)
# Out:
# image 1/1 c:\Users\jyes9\Desktop\PROJECT\github\open_source\object_detection\example.png: 448x640 6 persons, 1 bottle, 1 cup, 1 donut, 1 book, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Inference
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('example.png', imgsz=320, conf=0.5, save=True)
# Out:
# image 1/1 c:\Users\jyes9\Desktop\PROJECT\github\open_source\object_detection\example.png: 224x320 5 persons, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 39.9ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs\detect\predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
from PIL import Image
Image.open('runs/detect/predict/example.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x787>
